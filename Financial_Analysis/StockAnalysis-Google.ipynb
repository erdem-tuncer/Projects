# %%
#pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Requirement already satisfied: pandas>=0.23 in c:\users\erdem\anaconda3\lib\site-packages (from pandas-datareader) (1.2.4)
# Requirement already satisfied: lxml in c:\users\erdem\anaconda3\lib\site-packages (from pandas-datareader) (4.6.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\erdem\anaconda3\lib\site-packages (from pandas-datareader) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\erdem\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\erdem\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\erdem\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\erdem\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\erdem\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\erdem\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\erdem\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\erdem\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader.data as web
import datetime

# %%
start = datetime.datetime(2020,1,1)
end   = datetime.datetime(2020,4,17)

# %%
google = web.DataReader("GOOGL", 'yahoo', start, end)

# %%
google.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1368.680054  1346.489990  1348.410034  1368.680054  1363900
# 2020-01-03  1373.750000  1347.319946  1348.000000  1361.520020  1170400
# 2020-01-06  1398.319946  1351.000000  1351.630005  1397.810059  2338400
# 2020-01-07  1403.500000  1391.560059  1400.459961  1395.109985  1716500
# 2020-01-08  1411.849976  1392.630005  1394.819946  1405.040039  1765700
#
#               Adj Close
# Date
# 2020-01-02  1368.680054
# 2020-01-03  1361.520020
# 2020-01-06  1397.810059
# 2020-01-07  1395.109985
# 2020-01-08  1405.040039

# %%
google['Open']
# Out:
# Date
# 2020-01-02    1348.410034
# 2020-01-03    1348.000000
# 2020-01-06    1351.630005
# 2020-01-07    1400.459961
# 2020-01-08    1394.819946
#                  ...
# 2020-04-13    1201.500000
# 2020-04-14    1239.969971
# 2020-04-15    1246.510010
# 2020-04-16    1267.140015
# 2020-04-17    1281.699951
# Name: Open, Length: 74, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
google['Open'].plot()
plt.show;

# %%
google['Open'].plot(label= 'GOOGL Open Price', figsize=(15,7))
google['Close'].plot(label= 'GOOGL Close Price')
google['High'].plot(label= 'GOOGL High Price')
google['Low'].plot(label= 'GOOGL Low Price')
plt.legend()
plt.title('Google Stock Prices')
plt.ylabel('Stock Price')
plt.show;

# %%
google['Volume'].plot(figsize=(16,5))
plt.title('Volume Traded Google')
# Out:
# Text(0.5, 1.0, 'Volume Traded Google')
